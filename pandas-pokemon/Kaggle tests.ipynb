# %% [markdown]
# # Visualization of Pokémon stats

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# Load the data

# %%
df = pd.read_csv('../data/Pokemon.csv')
df.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation Legendary
# 0       65       65     45           1     False
# 1       80       80     60           1     False
# 2      100      100     80           1     False
# 3      122      120     80           1     False
# 4       60       50     65           1     False

# %% [markdown]
# Plot HP versus attack

# %%
sns.set(style="ticks", color_codes=True)
sns.jointplot(x="HP", y="Attack", data=df)

# %% [markdown]
# Attack VS Defense for legendary and non legendary Pokemons

# %%
sns.pairplot(df, vars=['Attack','Defense','Total'],  hue='Legendary', diag_kind='kde')
# Out:
# /root/miniconda3/envs/py3/lib/python3.4/site-packages/statsmodels/nonparametric/kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %%
sns.violinplot(data=df[['Attack','Defense', 'HP']])

# %%
f, ax = plt.subplots(figsize=(9, 6))
sns.heatmap(df.corr(), annot=True, linewidths=.5, ax=ax)
